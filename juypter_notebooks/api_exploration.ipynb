# %%
import json
from openaq import OpenAQ

# %%
# retrieve the key
with open("../api_key.json") as f:
    api_key = json.load(f)
    f.close()

openaq_key = api_key["openaq_api_key"]

# %%
# open the client
client = OpenAQ(api_key=openaq_key)
client

# %%
# Frame an area I'm interested in (around New York)
ny_bbox_search_locations = client.locations.list(
    bbox=(-74.279480,40.578477,-73.362121,40.983793),
    limit=1000
)

ny_bbox_search_locations.meta
# Out:
# Meta(name='openaq-api', website='/', page=1, limit=1000, found=53)

# %%
# Look at the result
ny_bbox_search_locations.results
# Out:
# [Location(id=384, name='CCNY', locality='New York-Northern New Jersey-Long Island', timezone='America/New_York', country=CountryBase(id=155, code='US', name='United States'), owner=OwnerBase(id=4, name='Unknown Governmental Organization'), provider=ProviderBase(id=119, name='AirNow'), is_mobile=False, is_monitor=True, instruments=[InstrumentBase(id=2, name='Government Monitor')], sensors=[SensorBase(id=671, name='o3 ppm', parameter=ParameterBase(id=10, name='o3', units='ppm', display_name='O₃')), SensorBase(id=673, name='pm25 µg/m³', parameter=ParameterBase(id=2, name='pm25', units='µg/m³', display_name='PM2.5'))], coordinates=Coordinates(latitude=40.8197, longitude=-73.9481), bounds=[-73.9481, 40.8197, -73.9481, 40.8197], distance=None, datetime_first=Datetime(utc='2016-03-12T09:00:00Z', local='2016-03-12T04:00:00-05:00'), datetime_last=Datetime(utc='2025-04-22T18:00:00Z', local='2025-04-22T14:00:00-04:00')),
#  Location(id=386, name='Susan Wagner', locality=None, timezone='America/New_York', country=CountryBase(id=155, code='US', name='United States'), owner=OwnerBase(id=4, name='Unknown Governmental Organization'), provider=ProviderBase(id=119, name='AirNow'), is_mobile=False, is_monitor=True, instruments=[InstrumentBase(id=2, name='Government Monitor')], sensors=[SensorBase(id=674, name='o3 ppm', parameter=ParameterBase(id=10, name='o3', units='ppm', display_name='O₃'))], coordinates=Coordinates(latitude=40.5969, longitude=-74.1264), bounds=[-74.1264, 40.5969, -74.1264, 40.5969], distance=None, datetime_first=Datetime(utc='2016-03-25T04:00:00Z', local='2016-03-25T00:00:00-04:00'), datetime_last=Datetime(utc='2017-11-15T22:00:00Z', local='2017-11-15T17:00:00-05:00')),
#  Location(id=392, name='Babylon', locality='New York-Northern New Jersey-Long Island', timezone='America/New_York', country=CountryBase(id=155, code='US', name='United States'), owner=OwnerBase(id=4, name='Unknown Governmental Organization'), provider=ProviderBase(id=119, name='AirNow'), is_mobile=False, is_monitor=True, instruments=[InstrumentBase(id=2, name='Government Monitor')], sensors=[SensorBase(id=683, name='o3 ppm', parameter=ParameterBase(id=10, name='o3', units='ppm', display_name='O₃'))], coordinates=Coordinates(latitude=40.7356, longitude=-73.4061), bounds=[-73.4061, 40.7356, -73.4061, 40.7356], distance=None, datetime_first=Datetime(utc='2016-03-12T02:00:00Z', local='2016-03-11T21:00:00-05:00'), datetime_last=Datetime(utc='2025-04-22T18:00:00Z', local='2025-04-22T14:00:00-04:00')),
#  Location(id=625, name='Manhattan/IS143', locality='New York-Northern New Jersey-Long Island', timezone='America/New_York', country=CountryBase(id=155, code='US', name='United States'), owner=OwnerBase(id=4, name='Unknown Governmental Organization'), provider=ProviderBase(id=119, name='AirNow'), is_mobile=False, is_monitor=True, instruments=[InstrumentBase(id=2, name='Government Monitor')], sensors=[SensorBase(id=1097, name='pm25 µg/m³', parameter=ParameterBase(id=2, name='pm25', units='µg/m³', display_name='PM2.5'))], coordinates=Coordinates(latitude=40.8492, longitude=-73.9319), bounds=[-73.9319, 40.8492, -73.9319, 40.8492], distance=None, datetime_first=Datetime(utc='2016-03-10T08:00:00Z', local='2016-03-10T03:00:00-05:00'), datetime_last=Datetime(utc='2025-04-22T18:00:00Z', local='2025-04-22T14:00:00-04:00')),
#  Location(id=626, name='Bronx - IS52', locality='New York-Northern New Jersey-Long Island', timezone='America/New_York', country=CountryBase(id=155, code='US', name='United States'), owner=OwnerBase(id=4, name='Unknown Governmental Organization'), provider=ProviderBase(id=119, name='AirNow'), is_mobile=False, is_monitor=True, instruments=[InstrumentBase(id=2, name='Government Monitor')], sensors=[SensorBase(id=1098, name='o3 ppm', parameter=ParameterBase(id=10, name='o3', units='ppm', display_name='O₃')), SensorBase(id=1099, name='pm10 µg/m³', parameter=ParameterBase(id=1, name='pm10', units='µg/m³', display_name='PM10')), SensorBase(id=1102, name='pm25 µg/m³', parameter=ParameterBase(id=2, name='pm25', units='µg/m³', display_name='PM2.5'))], coordinates=Coordinates(latitude=40.816101, longitude=-73.902199), bounds=[-73.902199, 40.816101, -73.902199, 40.816101], distance=None, datetime_first=Datetime(utc='2016-03-10T08:00:00Z', local='2016-03-10T03:00:00-05:00'), datetime_last=Datetime(utc='2025-04-22T18:00:00Z', local='2025-04-22T14:00:00-04:00')),
#  Location(id=628, name='Maspeth', locality='New York-Northern New Jersey-Long Island', timezone='America/New_York', country=CountryBase(id=155, code='US', name='United States'), owner=OwnerBase(id=4, name='Unknown Governmental Organization'), provider=ProviderBase(id=119, name='AirNow'), is_mobile=False, is_monitor=True, instruments=[InstrumentBase(id=2, name='Government Monitor')], sensors=[SensorBase(id=1103, name='pm25 µg/m³', parameter=ParameterBase(id=2, name='pm25', units='µg/m³', display_name='PM2.5'))], coordinates=Coordinates(latitude=40.7269, longitude=-73.8933), bounds=[-73.8933, 40.7269, -73.8933, 40.7269], distance=None, datetime_first=Datetime(utc='2016-03-10T08:00:00Z', local='2016-03-10T03:00:00-05:00'), datetime_last=Datetime(utc='2025-04-22T18:00:00Z', local='2025-04-22T14:00:00-04:00')),
#  Location(id=631, name='Queens', locality='New York-Northern New Jersey-Long Island', timezone='America/New_York', country=CountryBase(id=155, code='US', name='United States'), owner=OwnerBase(id=4, name='Unknown Governmental Organization'), provider=ProviderBase(id=119, name='AirNow'), is_mobile=False, is_monitor=True, instruments=[InstrumentBase(id=2, name='Government Monitor')], sensors=[SensorBase(id=1106, name='o3 ppm', parameter=ParameterBase(id=10, name='o3', units='ppm', display_name='O₃')), SensorBase(id=1152, name='pm25 µg/m³', parameter=ParameterBase(id=2, name='pm25', units='µg/m³', display_name='PM2.5'))], coordinates=Coordinates(latitude=40.7375, longitude=-73.8244), bounds=[-73.8244, 40.7375, -73.8244, 40.7375], distance=None, datetime_first=Datetime(utc='2016-03-10T08:00:00Z', local='2016-03-10T03:00:00-05:00'), datetime_last=Datetime(utc='2025-04-22T18:00:00Z', local='2025-04-22T14:00:00-04:00')),
#  Location(id=642, name='PS 19', locality=None, timezone='America/New_York', country=CountryBase(id=155, code='US', name='United States'), owner=OwnerBase(id=4, name='Unknown Governmental Organization'), provider=ProviderBase(id=119, name='AirNow'), is_mobile=False, is_monitor=True, instruments=[InstrumentBase(id=2, name='Government Monitor')], sensors=[SensorBase(id=1121, name='pm25 µg/m³', parameter=ParameterBase(id=2, name='pm25', units='µg/m³', display_name='PM2.5'))], coordinates=Coordinates(latitude=40.73, longitude=-73.984459), bounds=[-73.984459, 40.73, -73.984459, 40.73], distance=None, datetime_first=Datetime(utc='2016-03-10T08:00:00Z', local='2016-03-10T03:00:00-05:00'), datetime_last=Datetime(utc='2017-12-18T10:00:00Z', local='2017-12-18T05:00:00-05:00')),
#  Location(id=648, name='Bklyn - PS 314', locality='KINGS', timezone='America/New_York', country=CountryBase(id=155, code='US', name='United States'), owner=OwnerBase(id=4, name='Unknown Governmental Organization'), provider=ProviderBase(id=119, name='AirNow'), is_mobile=False, is_monitor=True, instruments=[InstrumentBase(id=2, name='Government Monitor')], sensors=[SensorBase(id=1128, name='pm25 µg/m³', parameter=ParameterBase(id=2, name='pm25', units='µg/m³', display_name='PM2.5'))], coordinates=Coordinates(latitude=40.641819, longitude=-74.018707), bounds=[-74.018707, 40.641819, -74.018707, 40.641819], distance=None, datetime_first=Datetime(utc='2016-03-10T08:00:00Z', local='2016-03-10T03:00:00-05:00'), datetime_last=Datetime(utc='2025-04-22T18:00:00Z', local='2025-04-22T14:00:00-04:00')),
#  Location(id=661, name='Eisenhower Park', locality='New York-Northern New Jersey-Long Island', timezone='America/New_York', country=CountryBase(id=155, code='US', name='United States'), owner=OwnerBase(id=4, name='Unknown Governmental Organization'), provider=ProviderBase(id=119, name='AirNow'), is_mobile=False, is_monitor=True, instruments=[InstrumentBase(id=2, name='Government Monitor')], sensors=[SensorBase(id=5077821, name='pm25 µg/m³', parameter=ParameterBase(id=2, name='pm25', units='µg/m³', display_name='PM2.5'))], coordinates=Coordinates(latitude=40.7447, longitude=-73.5869), bounds=[-73.5869, 40.7447, -73.5869, 40.7447], distance=None, datetime_first=Datetime(utc='2022-10-04T18:00:00Z', local='2022-10-04T14:00:00-04:00'), datetime_last=Datetime(utc='2023-10-20T15:00:00Z', local='2023-10-20T11:00:00-04:00')),
#  Location(id=662, name='Division Street', locality=None, timezone='America/New_York', country=CountryBase(id=155, code='US', name='United States'), owner=OwnerBase(id=4, name='Unknown Governmental Organization'), provider=ProviderBase(id=119, name='AirNow'), is_mobile=False, is_monitor=True, instruments=[InstrumentBase(id=2, name='Government Monitor')], sensors=[SensorBase(id=1143, name='pm25 µg/m³', parameter=ParameterBase(id=2, name='pm25', units='µg/m³', display_name='PM2.5'))], coordinates=Coordinates(latitude=40.7142, longitude=-73.995), bounds=[-73.995, 40.7142, -73.995, 40.7142], distance=None, datetime_first=Datetime(utc='2016-03-10T08:00:00Z', local='2016-03-10T03:00:00-05:00'), datetime_last=Datetime(utc='2020-02-19T16:00:00Z', local='2020-02-19T11:00:00-05:00')),
#  Location(id=664, name='Bklyn - PS274', locality='New York-Northern New Jersey-Long Island', timezone='America/New_York', country=CountryBase(id=155, code='US', name='United States'), owner=OwnerBase(id=4, name='Unknown Governmental Organization'), provider=ProviderBase(id=119, name='AirNow'), is_mobile=False, is_monitor=True, instruments=[InstrumentBase(id=2, name='Government Monitor')], sensors=[SensorBase(id=1145, name='pm25 µg/m³', parameter=ParameterBase(id=2, name='pm25', units='µg/m³', display_name='PM2.5'))], coordinates=Coordinates(latitude=40.694401, longitude=-73.928596), bounds=[-73.928596, 40.694401, -73.928596, 40.694401], distance=None, datetime_first=Datetime(utc='2016-03-10T08:00:00Z', local='2016-03-10T03:00:00-05:00'), datetime_last=Datetime(utc='2025-04-22T18:00:00Z', local='2025-04-22T14:00:00-04:00')),
#  Location(id=665, name='Bronx - IS74', locality='New York-Northern New Jersey-Long Island', timezone='America/New_York', country=CountryBase(id=155, code='US', name='United States'), owner=OwnerBase(id=4, name='Unknown Governmental Organization'), provider=ProviderBase(id=119, name='AirNow'), is_mobile=False, is_monitor=True, instruments=[InstrumentBase(id=2, name='Government Monitor')], sensors=[SensorBase(id=1146, name='pm25 µg/m³', parameter=ParameterBase(id=2, name='pm25', units='µg/m³', display_name='PM2.5'))], coordinates=Coordinates(latitude=40.814701, longitude=-73.886703), bounds=[-73.886703, 40.814701, -73.886703, 40.814701], distance=None, datetime_first=Datetime(utc='2016-03-10T08:00:00Z', local='2016-03-10T03:00:00-05:00'), datetime_last=Datetime(utc='2025-04-22T18:00:00Z', local='2025-04-22T14:00:00-04:00')),
#  Location(id=666, name='Pfizer Lab', locality='New York-Northern New Jersey-Long Island', timezone='America/New_York', country=CountryBase(id=155, code='US', name='United States'), owner=OwnerBase(id=4, name='Unknown Governmental Organization'), provider=ProviderBase(id=119, name='AirNow'), is_mobile=False, is_monitor=True, instruments=[InstrumentBase(id=2, name='Government Monitor')], sensors=[SensorBase(id=1147, name='o3 ppm', parameter=ParameterBase(id=10, name='o3', units='ppm', display_name='O₃'))], coordinates=Coordinates(latitude=40.868, longitude=-73.8782), bounds=[-73.8782, 40.868, -73.8782, 40.868], distance=None, datetime_first=Datetime(utc='2016-03-10T08:00:00Z', local='2016-03-10T03:00:00-05:00'), datetime_last=Datetime(utc='2025-04-22T18:00:00Z', local='2025-04-22T14:00:00-04:00')),
#  Location(id=853, name='East Orange', locality=None, timezone='America/New_York', country=CountryBase(id=155, code='US', name='United States'), owner=OwnerBase(id=4, name='Unknown Governmental Organization'), provider=ProviderBase(id=119, name='AirNow'), is_mobile=False, is_monitor=True, instruments=[InstrumentBase(id=2, name='Government Monitor')], sensors=[SensorBase(id=1522, name='co ppm', parameter=ParameterBase(id=8, name='co', units='ppm', display_name='CO')), SensorBase(id=1523, name='no2 ppm', parameter=ParameterBase(id=7, name='no2', units='ppm', display_name='NO₂'))], coordinates=Coordinates(latitude=40.7575, longitude=-74.2005), bounds=[-74.2005, 40.7575, -74.2005, 40.7575], distance=None, datetime_first=Datetime(utc='2016-03-06T20:00:00Z', local='2016-03-06T15:00:00-05:00'), datetime_last=Datetime(utc='2016-07-24T08:00:00Z', local='2016-07-24T04:00:00-04:00')),
#  Location(id=857, name='Fort Lee Near Road', locality='New York-Northern New Jersey-Long Island', timezone='America/New_York', country=CountryBase(id=155, code='US', name='United States'), owner=OwnerBase(id=4, name='Unknown Governmental Organization'), provider=ProviderBase(id=119, name='AirNow'), is_mobile=False, is_monitor=True, instruments=[InstrumentBase(id=2, name='Government Monitor')], sensors=[SensorBase(id=1536, name='co ppm', parameter=ParameterBase(id=8, name='co', units='ppm', display_name='CO')), SensorBase(id=4272431, name='no ppm', parameter=ParameterBase(id=35, name='no', units='ppm', display_name='NO')), SensorBase(id=1535, name='no2 ppm', parameter=ParameterBase(id=7, name='no2', units='ppm', display_name='NO₂')), SensorBase(id=4272250, name='nox ppm', parameter=ParameterBase(id=19840, name='nox', units='ppm', display_name='NOx')), SensorBase(id=1534, name='pm25 µg/m³', parameter=ParameterBase(id=2, name='pm25', units='µg/m³', display_name='PM2.5'))], coordinates=Coordinates(latitude=40.85355, longitude=-73.9661), bounds=[-73.9661, 40.85355, -73.9661, 40.85355], distance=None, datetime_first=Datetime(utc='2016-03-06T20:00:00Z', local='2016-03-06T15:00:00-05:00'), datetime_last=Datetime(utc='2025-04-22T18:00:00Z', local='2025-04-22T14:00:00-04:00')),
#  Location(id=924, name='Rahway PM', locality='New York-Northern New Jersey-Long Island', timezone='America/New_York', country=CountryBase(id=155, code='US', name='United States'), owner=OwnerBase(id=4, name='Unknown Governmental Organization'), provider=ProviderBase(id=119, name='AirNow'), is_mobile=False, is_monitor=True, instruments=[InstrumentBase(id=2, name='Government Monitor')], sensors=[SensorBase(id=1693, name='pm25 µg/m³', parameter=ParameterBase(id=2, name='pm25', units='µg/m³', display_name='PM2.5'))], coordinates=Coordinates(latitude=40.603943, longitude=-74.276176), bounds=[-74.276176, 40.603943, -74.276176, 40.603943], distance=None, datetime_first=Datetime(utc='2016-03-06T20:00:00Z', local='2016-03-06T15:00:00-05:00'), datetime_last=Datetime(utc='2025-04-22T18:00:00Z', local='2025-04-22T14:00:00-04:00')),
#  Location(id=928, name='Jersey City FH', locality='New York-Northern New Jersey-Long Island', timezone='America/New_York', country=CountryBase(id=155, code='US', name='United States'), owner=OwnerBase(id=4, name='Unknown Governmental Organization'), provider=ProviderBase(id=119, name='AirNow'), is_mobile=False, is_monitor=True, instruments=[InstrumentBase(id=2, name='Government Monitor')], sensors=[SensorBase(id=5077566, name='pm25 µg/m³', parameter=ParameterBase(id=2, name='pm25', units='µg/m³', display_name='PM2.5'))], coordinates=Coordinates(latitude=40.725452, longitude=-74.052292), bounds=[-74.052292, 40.725452, -74.052292, 40.725452], distance=None, datetime_first=Datetime(utc='2023-05-07T01:00:00Z', local='2023-05-06T21:00:00-04:00'), datetime_last=Datetime(utc='2025-04-22T18:00:00Z', local='2025-04-22T14:00:00-04:00')),
#  Location(id=971, name='Elizabeth Trailer', locality='New York-Northern New Jersey-Long Island', timezone='America/New_York', country=CountryBase(id=155, code='US', name='United States'), owner=OwnerBase(id=4, name='Unknown Governmental Organization'), provider=ProviderBase(id=119, name='AirNow'), is_mobile=False, is_monitor=True, instruments=[InstrumentBase(id=2, name='Government Monitor')], sensors=[SensorBase(id=3952, name='co ppm', parameter=ParameterBase(id=8, name='co', units='ppm', display_name='CO')), SensorBase(id=4272273, name='no ppm', parameter=ParameterBase(id=35, name='no', units='ppm', display_name='NO')), SensorBase(id=3951, name='no2 ppm', parameter=ParameterBase(id=7, name='no2', units='ppm', display_name='NO₂')), SensorBase(id=4272290, name='nox ppm', parameter=ParameterBase(id=19840, name='nox', units='ppm', display_name='NOx')), SensorBase(id=1758, name='pm25 µg/m³', parameter=ParameterBase(id=2, name='pm25', units='µg/m³', display_name='PM2.5')), SensorBase(id=3950, name='so2 ppm', parameter=ParameterBase(id=9, name='so2', units='ppm', display_name='SO₂'))], coordinates=Coordinates(latitude=40.64144099999999, longitude=-74.208366), bounds=[-74.208366, 40.64144099999999, -74.208366, 40.64144099999999], distance=None, datetime_first=Datetime(utc='2016-03-06T20:00:00Z', local='2016-03-06T15:00:00-05:00'), datetime_last=Datetime(utc='2025-04-22T18:00:00Z', local='2025-04-22T14:00:00-04:00')),
#  Location(id=974, name='Newark Firehouse', locality=None, timezone='America/New_York', country=CountryBase(id=155, code='US', name='United States'), owner=OwnerBase(id=4, name='Unknown Governmental Organization'), provider=ProviderBase(id=119, name='AirNow'), is_mobile=False, is_monitor=True, instruments=[InstrumentBase(id=2, name='Government Monitor')], sensors=[SensorBase(id=3637, name='co ppm', parameter=ParameterBase(id=8, name='co', units='ppm', display_name='CO')), SensorBase(id=3638, name='no2 ppm', parameter=ParameterBase(id=7, name='no2', units='ppm', display_name='NO₂')), SensorBase(id=3639, name='o3 ppm', parameter=ParameterBase(id=10, name='o3', units='ppm', display_name='O₃')), SensorBase(id=1761, name='pm25 µg/m³', parameter=ParameterBase(id=2, name='pm25', units='µg/m³', display_name='PM2.5')), SensorBase(id=3640, name='so2 ppm', parameter=ParameterBase(id=9, name='so2', units='ppm', display_name='SO₂'))], coordinates=Coordinates(latitude=40.720989, longitude=-74.192894), bounds=[-74.192894, 40.720989, -74.192894, 40.720989], distance=None, datetime_first=Datetime(utc='2016-03-06T20:00:00Z', local='2016-03-06T15:00:00-05:00'), datetime_last=Datetime(utc='2022-09-26T11:00:00Z', local='2022-09-26T07:00:00-04:00')),
#  Location(id=984, name='Leonia', locality='New York-Northern New Jersey-Long Island', timezone='America/New_York', country=CountryBase(id=155, code='US', name='United States'), owner=OwnerBase(id=4, name='Unknown Governmental Organization'), provider=ProviderBase(id=119, name='AirNow'), is_mobile=False, is_monitor=True, instruments=[InstrumentBase(id=2, name='Government Monitor')], sensors=[SensorBase(id=1777, name='o3 ppm', parameter=ParameterBase(id=10, name='o3', units='ppm', display_name='O₃'))], coordinates=Coordinates(latitude=40.870438, longitude=-73.991997), bounds=[-73.991997, 40.870438, -73.991997, 40.870438], distance=None, datetime_first=Datetime(utc='2016-03-10T08:00:00Z', local='2016-03-10T03:00:00-05:00'), datetime_last=Datetime(utc='2025-04-22T18:00:00Z', local='2025-04-22T14:00:00-04:00')),
#  Location(id=1122, name='Jersey City', locality='New York-Northern New Jersey-Long Island', timezone='America/New_York', country=CountryBase(id=155, code='US', name='United States'), owner=OwnerBase(id=4, name='Unknown Governmental Organization'), provider=ProviderBase(id=119, name='AirNow'), is_mobile=False, is_monitor=True, instruments=[InstrumentBase(id=2, name='Government Monitor')], sensors=[SensorBase(id=2016, name='co ppm', parameter=ParameterBase(id=8, name='co', units='ppm', display_name='CO')), SensorBase(id=4272352, name='no ppm', parameter=ParameterBase(id=35, name='no', units='ppm', display_name='NO')), SensorBase(id=23341, name='no2 ppm', parameter=ParameterBase(id=7, name='no2', units='ppm', display_name='NO₂')), SensorBase(id=4272080, name='nox ppm', parameter=ParameterBase(id=19840, name='nox', units='ppm', display_name='NOx')), SensorBase(id=2018, name='so2 ppm', parameter=ParameterBase(id=9, name='so2', units='ppm', display_name='SO₂'))], coordinates=Coordinates(latitude=40.731689, longitude=-74.066566), bounds=[-74.066566, 40.731689, -74.066566, 40.731689], distance=None, datetime_first=Datetime(utc='2016-03-06T20:00:00Z', local='2016-03-06T15:00:00-05:00'), datetime_last=Datetime(utc='2025-04-22T18:00:00Z', local='2025-04-22T14:00:00-04:00')),
#  Location(id=1496, name='Bayonne', locality='New York-Northern New Jersey-Long Island', timezone='America/New_York', country=CountryBase(id=155, code='US', name='United States'), owner=OwnerBase(id=4, name='Unknown Governmental Organization'), provider=ProviderBase(id=119, name='AirNow'), is_mobile=False, is_monitor=True, instruments=[InstrumentBase(id=2, name='Government Monitor')], sensors=[SensorBase(id=4272224, name='no ppm', parameter=ParameterBase(id=35, name='no', units='ppm', display_name='NO')), SensorBase(id=2644, name='no2 ppm', parameter=ParameterBase(id=7, name='no2', units='ppm', display_name='NO₂')), SensorBase(id=4272086, name='nox ppm', parameter=ParameterBase(id=19840, name='nox', units='ppm', display_name='NOx')), SensorBase(id=2645, name='o3 ppm', parameter=ParameterBase(id=10, name='o3', units='ppm', display_name='O₃')), SensorBase(id=2646, name='so2 ppm', parameter=ParameterBase(id=9, name='so2', units='ppm', display_name='SO₂'))], coordinates=Coordinates(latitude=40.67025, longitude=-74.126083), bounds=[-74.126083, 40.67025, -74.126083, 40.67025], distance=None, datetime_first=Datetime(utc='2016-03-06T20:00:00Z', local='2016-03-06T15:00:00-05:00'), datetime_last=Datetime(utc='2025-04-22T18:00:00Z', local='2025-04-22T14:00:00-04:00')),
#  Location(id=2193, name='Elizabeth', locality='UNION', timezone='America/New_York', country=CountryBase(id=155, code='US', name='United States'), owner=OwnerBase(id=4, name='Unknown Governmental Organization'), provider=ProviderBase(id=119, name='AirNow'), is_mobile=False, is_monitor=True, instruments=[InstrumentBase(id=2, name='Government Monitor')], sensors=[SensorBase(id=3954, name='co ppm', parameter=ParameterBase(id=8, name='co', units='ppm', display_name='CO')), SensorBase(id=3953, name='so2 ppm', parameter=ParameterBase(id=9, name='so2', units='ppm', display_name='SO₂'))], coordinates=Coordinates(latitude=40.662388, longitude=-74.214813), bounds=[-74.214813, 40.662388, -74.214813, 40.662388], distance=None, datetime_first=Datetime(utc='2016-03-06T20:00:00Z', local='2016-03-06T15:00:00-05:00'), datetime_last=Datetime(utc='2024-04-05T11:00:00Z', local='2024-04-05T07:00:00-04:00')),
#  Location(id=8749, name='Queens Near-road', locality='New York-Northern New Jersey-Long Island', timezone='America/New_York', country=CountryBase(id=155, code='US', name='United States'), owner=OwnerBase(id=4, name='Unknown Governmental Organization'), provider=ProviderBase(id=119, name='AirNow'), is_mobile=False, is_monitor=True, instruments=[InstrumentBase(id=2, name='Government Monitor')], sensors=[SensorBase(id=25520, name='pm25 µg/m³', parameter=ParameterBase(id=2, name='pm25', units='µg/m³', display_name='PM2.5'))], coordinates=Coordinates(latitude=40.739264, longitude=-73.817694), bounds=[-73.817694, 40.739264, -73.817694, 40.739264], distance=None, datetime_first=Datetime(utc='2018-03-16T16:00:00Z', local='2018-03-16T12:00:00-04:00'), datetime_last=Datetime(utc='2023-09-07T09:00:00Z', local='2023-09-07T05:00:00-04:00')),
#  Location(id=292229, name='Morrisania', locality='New York-Northern New Jersey-Long Island', timezone='America/New_York', country=CountryBase(id=155, code='US', name='United States'), owner=OwnerBase(id=4, name='Unknown Governmental Organization'), provider=ProviderBase(id=119, name='AirNow'), is_mobile=False, is_monitor=True, instruments=[InstrumentBase(id=2, name='Government Monitor')], sensors=[SensorBase(id=1662910, name='pm25 µg/m³', parameter=ParameterBase(id=2, name='pm25', units='µg/m³', display_name='PM2.5'))], coordinates=Coordinates(latitude=40.8367, longitude=-73.9214), bounds=[-73.9214, 40.8367, -73.9214, 40.8367], distance=None, datetime_first=Datetime(utc='2022-02-23T13:00:00Z', local='2022-02-23T08:00:00-05:00'), datetime_last=Datetime(utc='2025-04-22T18:00:00Z', local='2025-04-22T14:00:00-04:00')),
#  Location(id=387315, name='Union City High Scho', locality='New York-Northern New Jersey-Long Island', timezone='America/New_York', country=CountryBase(id=155, code='US', name='United States'), owner=OwnerBase(id=4, name='Unknown Governmental Organization'), provider=ProviderBase(id=119, name='AirNow'), is_mobile=False, is_monitor=True, instruments=[InstrumentBase(id=2, name='Government Monitor')], sensors=[SensorBase(id=2165515, name='pm25 µg/m³', parameter=ParameterBase(id=2, name='pm25', units='µg/m³', display_name='PM2.5'))], coordinates=Coordinates(latitude=40.770908, longitude=-74.036218), bounds=[-74.036218, 40.770908, -74.036218, 40.770908], distance=None, datetime_first=Datetime(utc='2022-11-23T01:00:00Z', local='2022-11-22T20:00:00-05:00'), datetime_last=Datetime(utc='2025-04-22T18:00:00Z', local='2025-04-22T14:00:00-04:00')),
#  Location(id=391818, name='Paterson', locality='New York-Northern New Jersey-Long Island', timezone='America/New_York', country=CountryBase(id=155, code='US', name='United States'), owner=OwnerBase(id=4, name='Unknown Governmental Organization'), provider=ProviderBase(id=119, name='AirNow'), is_mobile=False, is_monitor=True, instruments=[InstrumentBase(id=2, name='Government Monitor')], sensors=[SensorBase(id=2189530, name='pm25 µg/m³', parameter=ParameterBase(id=2, name='pm25', units='µg/m³', display_name='PM2.5'))], coordinates=Coordinates(latitude=40.918381, longitude=-74.168092), bounds=[-74.168092, 40.918381, -74.168092, 40.918381], distance=None, datetime_first=Datetime(utc='2022-11-29T17:00:00Z', local='2022-11-29T12:00:00-05:00'), datetime_last=Datetime(utc='2025-04-22T18:00:00Z', local='2025-04-22T14:00:00-04:00')),
#  Location(id=496096, name='Port Richmond', locality='RICHMOND', timezone='America/New_York', country=CountryBase(id=155, code='US', name='United States'), owner=OwnerBase(id=4, name='Unknown Governmental Organization'), provider=ProviderBase(id=119, name='AirNow'), is_mobile=False, is_monitor=True, instruments=[InstrumentBase(id=2, name='Government Monitor')], sensors=[SensorBase(id=2780575, name='pm25 µg/m³', parameter=ParameterBase(id=2, name='pm25', units='µg/m³', display_name='PM2.5'))], coordinates=Coordinates(latitude=40.63306, longitude=-74.137156), bounds=[-74.137156, 40.63306, -74.137156, 40.63306], distance=None, datetime_first=Datetime(utc='2023-01-16T18:00:00Z', local='2023-01-16T13:00:00-05:00'), datetime_last=Datetime(utc='2025-04-22T18:00:00Z', local='2025-04-22T14:00:00-04:00')),
#  Location(id=1236005, name='Larchmont, NY', locality=None, timezone='America/New_York', country=CountryBase(id=155, code='US', name='United States'), owner=OwnerBase(id=4, name='Unknown Governmental Organization'), provider=ProviderBase(id=66, name='AirGradient'), is_mobile=False, is_monitor=False, instruments=[InstrumentBase(id=1, name='N/A'), InstrumentBase(id=7, name='AirGradient Sensor')], sensors=[SensorBase(id=7978991, name='pm1 µg/m³', parameter=ParameterBase(id=19, name='pm1', units='µg/m³', display_name='PM1')), SensorBase(id=7971030, name='pm1 µg/m³', parameter=ParameterBase(id=19, name='pm1', units='µg/m³', display_name='PM1')), SensorBase(id=7971117, name='pm10 µg/m³', parameter=ParameterBase(id=1, name='pm10', units='µg/m³', display_name='PM10')), SensorBase(id=7979020, name='pm10 µg/m³', parameter=ParameterBase(id=1, name='pm10', units='µg/m³', display_name='PM10')), SensorBase(id=6530200, name='pm25 µg/m³', parameter=ParameterBase(id=2, name='pm25', units='µg/m³', display_name='PM2.5')), SensorBase(id=7972295, name='relativehumidity %', parameter=ParameterBase(id=98, name='relativehumidity', units='%', display_name='RH')), SensorBase(id=6530188, name='temperature c', parameter=ParameterBase(id=100, name='temperature', units='c', display_name='Temperature (C)')), SensorBase(id=7972258, name='um003 particles/cm³', parameter=ParameterBase(id=125, name='um003', units='particles/cm³', display_name='PM0.3 count'))], coordinates=Coordinates(latitude=40.940119, longitude=-73.7561704), bounds=[-73.7561704, 40.940119, -73.7561704, 40.940119], distance=None, datetime_first=Datetime(utc='2023-07-15T13:00:00Z', local='2023-07-15T09:00:00-04:00'), datetime_last=Datetime(utc='2025-03-17T03:00:00Z', local='2025-03-16T23:00:00-04:00')),
#  Location(id=1236043, name='Franklin Avenue', locality=None, timezone='America/New_York', country=CountryBase(id=155, code='US', name='United States'), owner=OwnerBase(id=4, name='Unknown Governmental Organization'), provider=ProviderBase(id=66, name='AirGradient'), is_mobile=False, is_monitor=False, instruments=[InstrumentBase(id=7, name='AirGradient Sensor')], sensors=[SensorBase(id=6530280, name='pm25 µg/m³', parameter=ParameterBase(id=2, name='pm25', units='µg/m³', display_name='PM2.5')), SensorBase(id=6530283, name='temperature c', parameter=ParameterBase(id=100, name='temperature', units='c', display_name='Temperature (C)'))], coordinates=Coordinates(latitude=40.6753647214196, longitude=-73.9563637596401), bounds=[-73.9563637596401, 40.6753647214196, -73.9563637596401, 40.6753647214196], distance=None, datetime_first=Datetime(utc='2023-07-15T13:00:00Z', local='2023-07-15T09:00:00-04:00'), datetime_last=Datetime(utc='2023-11-15T21:00:00Z', local='2023-11-15T16:00:00-05:00')),
#  Location(id=1738519, name='Bayside, NY', locality=None, timezone='America/New_York', country=CountryBase(id=155, code='US', name='United States'), owner=OwnerBase(id=11509, name='Unknown Person'), provider=ProviderBase(id=66, name='AirGradient'), is_mobile=False, is_monitor=False, instruments=[InstrumentBase(id=7, name='AirGradient Sensor')], sensors=[SensorBase(id=7254050, name='pm25 µg/m³', parameter=ParameterBase(id=2, name='pm25', units='µg/m³', display_name='PM2.5')), SensorBase(id=7254073, name='temperature c', parameter=ParameterBase(id=100, name='temperature', units='c', display_name='Temperature (C)'))], coordinates=Coordinates(latitude=40.76435896908956, longitude=-73.76633003003028), bounds=[-73.76633003003028, 40.76435896908956, -73.76633003003028, 40.76435896908956], distance=None, datetime_first=Datetime(utc='2023-10-22T03:00:00Z', local='2023-10-21T23:00:00-04:00'), datetime_last=Datetime(utc='2023-11-04T02:00:00Z', local='2023-11-03T22:00:00-04:00')),
#  Location(id=1775647, name='State Dept of Environmental Conservation', locality=None, timezone='America/New_York', country=CountryBase(id=155, code='US', name='United States'), owner=OwnerBase(id=11509, name='Unknown Person'), provider=ProviderBase(id=66, name='AirGradient'), is_mobile=False, is_monitor=False, instruments=[InstrumentBase(id=7, name='AirGradient Sensor'), InstrumentBase(id=7, name='AirGradient Sensor')], sensors=[SensorBase(id=7978166, name='pm1 µg/m³', parameter=ParameterBase(id=19, name='pm1', units='µg/m³', display_name='PM1')), SensorBase(id=7970982, name='pm1 µg/m³', parameter=ParameterBase(id=19, name='pm1', units='µg/m³', display_name='PM1')), SensorBase(id=7971373, name='pm10 µg/m³', parameter=ParameterBase(id=1, name='pm10', units='µg/m³', display_name='PM10')), SensorBase(id=7978193, name='pm10 µg/m³', parameter=ParameterBase(id=1, name='pm10', units='µg/m³', display_name='PM10')), SensorBase(id=7324143, name='pm25 µg/m³', parameter=ParameterBase(id=2, name='pm25', units='µg/m³', display_name='PM2.5')), SensorBase(id=7972608, name='relativehumidity %', parameter=ParameterBase(id=98, name='relativehumidity', units='%', display_name='RH')), SensorBase(id=7324145, name='temperature c', parameter=ParameterBase(id=100, name='temperature', units='c', display_name='Temperature (C)')), SensorBase(id=7972609, name='um003 particles/cm³', parameter=ParameterBase(id=125, name='um003', units='particles/cm³', display_name='PM0.3 count'))], coordinates=Coordinates(latitude=40.7380471586139, longitude=-73.82013798686398), bounds=[-73.82013798686398, 40.7380471586139, -73.82013798686398, 40.7380471586139], distance=None, datetime_first=Datetime(utc='2023-10-30T08:00:00Z', local='2023-10-30T04:00:00-04:00'), datetime_last=Datetime(utc='2024-11-16T02:00:00Z', local='2024-11-15T21:00:00-05:00')),
#  Location(id=1824516, name='Bayside, NY', locality=None, timezone='America/New_York', country=CountryBase(id=155, code='US', name='United States'), owner=OwnerBase(id=11509, name='Unknown Person'), provider=ProviderBase(id=66, name='AirGradient'), is_mobile=False, is_monitor=False, instruments=[InstrumentBase(id=7, name='AirGradient Sensor'), InstrumentBase(id=7, name='AirGradient Sensor')], sensors=[SensorBase(id=7971082, name='pm1 µg/m³', parameter=ParameterBase(id=19, name='pm1', units='µg/m³', display_name='PM1')), SensorBase(id=7979835, name='pm1 µg/m³', parameter=ParameterBase(id=19, name='pm1', units='µg/m³', display_name='PM1')), SensorBase(id=7979816, name='pm10 µg/m³', parameter=ParameterBase(id=1, name='pm10', units='µg/m³', display_name='PM10')), SensorBase(id=7971073, name='pm10 µg/m³', parameter=ParameterBase(id=1, name='pm10', units='µg/m³', display_name='PM10')), SensorBase(id=7386938, name='pm25 µg/m³', parameter=ParameterBase(id=2, name='pm25', units='µg/m³', display_name='PM2.5')), SensorBase(id=7972707, name='relativehumidity %', parameter=ParameterBase(id=98, name='relativehumidity', units='%', display_name='RH')), SensorBase(id=7386942, name='temperature c', parameter=ParameterBase(id=100, name='temperature', units='c', display_name='Temperature (C)')), SensorBase(id=7972670, name='um003 particles/cm³', parameter=ParameterBase(id=125, name='um003', units='particles/cm³', display_name='PM0.3 count'))], coordinates=Coordinates(latitude=40.764348694977386, longitude=-73.76633985508255), bounds=[-73.76633985508255, 40.764348694977386, -73.76633985508255, 40.764348694977386], distance=None, datetime_first=Datetime(utc='2023-11-11T04:00:00Z', local='2023-11-10T23:00:00-05:00'), datetime_last=Datetime(utc='2025-02-16T15:00:00Z', local='2025-02-16T10:00:00-05:00')),
#  Location(id=2153518, name='Jersey City Heights', locality=None, timezone='America/New_York', country=CountryBase(id=155, code='US', name='United States'), owner=OwnerBase(id=11509, name='Unknown Person'), provider=ProviderBase(id=66, name='AirGradient'), is_mobile=False, is_monitor=False, instruments=[InstrumentBase(id=7, name='AirGradient Sensor'), InstrumentBase(id=7, name='AirGradient Sensor')], sensors=[SensorBase(id=7970916, name='pm1 µg/m³', parameter=ParameterBase(id=19, name='pm1', units='µg/m³', display_name='PM1')), SensorBase(id=7979411, name='pm1 µg/m³', parameter=ParameterBase(id=19, name='pm1', units='µg/m³', display_name='PM1')), SensorBase(id=7979380, name='pm10 µg/m³', parameter=ParameterBase(id=1, name='pm10', units='µg/m³', display_name='PM10')), SensorBase(id=7970930, name='pm10 µg/m³', parameter=ParameterBase(id=1, name='pm10', units='µg/m³', display_name='PM10')), SensorBase(id=7979399, name='pm25 µg/m³', parameter=ParameterBase(id=2, name='pm25', units='µg/m³', display_name='PM2.5')), SensorBase(id=7763001, name='pm25 µg/m³', parameter=ParameterBase(id=2, name='pm25', units='µg/m³', display_name='PM2.5')), SensorBase(id=7971870, name='relativehumidity %', parameter=ParameterBase(id=98, name='relativehumidity', units='%', display_name='RH')), SensorBase(id=7979412, name='temperature c', parameter=ParameterBase(id=100, name='temperature', units='c', display_name='Temperature (C)')), SensorBase(id=7762999, name='temperature c', parameter=ParameterBase(id=100, name='temperature', units='c', display_name='Temperature (C)')), SensorBase(id=7971901, name='um003 particles/cm³', parameter=ParameterBase(id=125, name='um003', units='particles/cm³', display_name='PM0.3 count'))], coordinates=Coordinates(latitude=40.75065, longitude=-74.04252), bounds=[-74.04252, 40.75065, -74.04252, 40.75065], distance=None, datetime_first=Datetime(utc='2024-01-28T00:00:00Z', local='2024-01-27T19:00:00-05:00'), datetime_last=Datetime(utc='2025-04-06T21:00:00Z', local='2025-04-06T17:00:00-04:00')),
#  Location(id=2386747, name='Carteret, NJ', locality=None, timezone='America/New_York', country=CountryBase(id=155, code='US', name='United States'), owner=OwnerBase(id=11509, name='Unknown Person'), provider=ProviderBase(id=66, name='AirGradient'), is_mobile=False, is_monitor=False, instruments=[InstrumentBase(id=7, name='AirGradient Sensor'), InstrumentBase(id=7, name='AirGradient Sensor')], sensors=[SensorBase(id=7979444, name='pm1 µg/m³', parameter=ParameterBase(id=19, name='pm1', units='µg/m³', display_name='PM1')), SensorBase(id=7971145, name='pm1 µg/m³', parameter=ParameterBase(id=19, name='pm1', units='µg/m³', display_name='PM1')), SensorBase(id=7979475, name='pm10 µg/m³', parameter=ParameterBase(id=1, name='pm10', units='µg/m³', display_name='PM10')), SensorBase(id=7971292, name='pm10 µg/m³', parameter=ParameterBase(id=1, name='pm10', units='µg/m³', display_name='PM10')), SensorBase(id=7815388, name='pm25 µg/m³', parameter=ParameterBase(id=2, name='pm25', units='µg/m³', display_name='PM2.5')), SensorBase(id=7971629, name='relativehumidity %', parameter=ParameterBase(id=98, name='relativehumidity', units='%', display_name='RH')), SensorBase(id=7815389, name='temperature c', parameter=ParameterBase(id=100, name='temperature', units='c', display_name='Temperature (C)')), SensorBase(id=7971668, name='um003 particles/cm³', parameter=ParameterBase(id=125, name='um003', units='particles/cm³', display_name='PM0.3 count'))], coordinates=Coordinates(latitude=40.585, longitude=-74.238), bounds=[-74.238, 40.585, -74.238, 40.585], distance=None, datetime_first=Datetime(utc='2024-02-05T22:00:00Z', local='2024-02-05T17:00:00-05:00'), datetime_last=Datetime(utc='2025-04-22T18:00:00Z', local='2025-04-22T14:00:00-04:00')),
#  Location(id=2453305, name='State Dept of Environmental Conservation', locality=None, timezone='America/New_York', country=CountryBase(id=155, code='US', name='United States'), owner=OwnerBase(id=11509, name='Unknown Person'), provider=ProviderBase(id=66, name='AirGradient'), is_mobile=False, is_monitor=False, instruments=[InstrumentBase(id=7, name='AirGradient Sensor'), InstrumentBase(id=7, name='AirGradient Sensor')], sensors=[SensorBase(id=7971316, name='pm1 µg/m³', parameter=ParameterBase(id=19, name='pm1', units='µg/m³', display_name='PM1')), SensorBase(id=7979901, name='pm1 µg/m³', parameter=ParameterBase(id=19, name='pm1', units='µg/m³', display_name='PM1')), SensorBase(id=7979909, name='pm10 µg/m³', parameter=ParameterBase(id=1, name='pm10', units='µg/m³', display_name='PM10')), SensorBase(id=7971262, name='pm10 µg/m³', parameter=ParameterBase(id=1, name='pm10', units='µg/m³', display_name='PM10')), SensorBase(id=7897339, name='pm25 µg/m³', parameter=ParameterBase(id=2, name='pm25', units='µg/m³', display_name='PM2.5')), SensorBase(id=7972696, name='relativehumidity %', parameter=ParameterBase(id=98, name='relativehumidity', units='%', display_name='RH')), SensorBase(id=7897332, name='temperature c', parameter=ParameterBase(id=100, name='temperature', units='c', display_name='Temperature (C)')), SensorBase(id=7972703, name='um003 particles/cm³', parameter=ParameterBase(id=125, name='um003', units='particles/cm³', display_name='PM0.3 count'))], coordinates=Coordinates(latitude=40.73742886695366, longitude=-73.82036241535091), bounds=[-73.82036241535091, 40.73742886695366, -73.82036241535091, 40.73742886695366], distance=None, datetime_first=Datetime(utc='2024-02-20T14:00:00Z', local='2024-02-20T09:00:00-05:00'), datetime_last=Datetime(utc='2024-11-16T02:00:00Z', local='2024-11-15T21:00:00-05:00')),
#  Location(id=2453313, name='State Dept of Environmental Conservation', locality=None, timezone='America/New_York', country=CountryBase(id=155, code='US', name='United States'), owner=OwnerBase(id=11509, name='Unknown Person'), provider=ProviderBase(id=66, name='AirGradient'), is_mobile=False, is_monitor=False, instruments=[InstrumentBase(id=7, name='AirGradient Sensor'), InstrumentBase(id=7, name='AirGradient Sensor')], sensors=[SensorBase(id=7971247, name='pm1 µg/m³', parameter=ParameterBase(id=19, name='pm1', units='µg/m³', display_name='PM1')), SensorBase(id=7979861, name='pm1 µg/m³', parameter=ParameterBase(id=19, name='pm1', units='µg/m³', display_name='PM1')), SensorBase(id=7979870, name='pm10 µg/m³', parameter=ParameterBase(id=1, name='pm10', units='µg/m³', display_name='PM10')), SensorBase(id=7970808, name='pm10 µg/m³', parameter=ParameterBase(id=1, name='pm10', units='µg/m³', display_name='PM10')), SensorBase(id=7897355, name='pm25 µg/m³', parameter=ParameterBase(id=2, name='pm25', units='µg/m³', display_name='PM2.5')), SensorBase(id=7972702, name='relativehumidity %', parameter=ParameterBase(id=98, name='relativehumidity', units='%', display_name='RH')), SensorBase(id=7897354, name='temperature c', parameter=ParameterBase(id=100, name='temperature', units='c', display_name='Temperature (C)')), SensorBase(id=7972671, name='um003 particles/cm³', parameter=ParameterBase(id=125, name='um003', units='particles/cm³', display_name='PM0.3 count'))], coordinates=Coordinates(latitude=40.7380471586139, longitude=-73.82013798686398), bounds=[-73.82013798686398, 40.7380471586139, -73.82013798686398, 40.7380471586139], distance=None, datetime_first=Datetime(utc='2024-02-20T14:00:00Z', local='2024-02-20T09:00:00-05:00'), datetime_last=Datetime(utc='2024-11-16T02:00:00Z', local='2024-11-15T21:00:00-05:00')),
#  Location(id=2616564, name='7th Ave and W 16th St', locality=None, timezone='America/New_York', country=CountryBase(id=155, code='US', name='United States'), owner=OwnerBase(id=11509, name='Unknown Person'), provider=ProviderBase(id=66, name='AirGradient'), is_mobile=False, is_monitor=False, instruments=[InstrumentBase(id=7, name='AirGradient Sensor')], sensors=[SensorBase(id=8520935, name='pm1 µg/m³', parameter=ParameterBase(id=19, name='pm1', units='µg/m³', display_name='PM1')), SensorBase(id=8520936, name='pm10 µg/m³', parameter=ParameterBase(id=1, name='pm10', units='µg/m³', display_name='PM10')), SensorBase(id=8520925, name='pm25 µg/m³', parameter=ParameterBase(id=2, name='pm25', units='µg/m³', display_name='PM2.5')), SensorBase(id=8520920, name='relativehumidity %', parameter=ParameterBase(id=98, name='relativehumidity', units='%', display_name='RH')), SensorBase(id=8520938, name='temperature c', parameter=ParameterBase(id=100, name='temperature', units='c', display_name='Temperature (C)')), SensorBase(id=8520933, name='um003 particles/cm³', parameter=ParameterBase(id=125, name='um003', units='particles/cm³', display_name='PM0.3 count'))], coordinates=Coordinates(latitude=40.740022, longitude=-73.998504), bounds=[-73.998504, 40.740022, -73.998504, 40.740022], distance=None, datetime_first=Datetime(utc='2024-03-18T19:00:00Z', local='2024-03-18T15:00:00-04:00'), datetime_last=Datetime(utc='2025-04-22T18:00:00Z', local='2025-04-22T14:00:00-04:00')),
#  Location(id=2903996, name='Win Son', locality=None, timezone='America/New_York', country=CountryBase(id=155, code='US', name='United States'), owner=OwnerBase(id=11509, name='Unknown Person'), provider=ProviderBase(id=66, name='AirGradient'), is_mobile=False, is_monitor=False, instruments=[InstrumentBase(id=7, name='AirGradient Sensor')], sensors=[SensorBase(id=9648782, name='pm1 µg/m³', parameter=ParameterBase(id=19, name='pm1', units='µg/m³', display_name='PM1')), SensorBase(id=9648783, name='pm10 µg/m³', parameter=ParameterBase(id=1, name='pm10', units='µg/m³', display_name='PM10')), SensorBase(id=9648812, name='pm25 µg/m³', parameter=ParameterBase(id=2, name='pm25', units='µg/m³', display_name='PM2.5')), SensorBase(id=9648774, name='relativehumidity %', parameter=ParameterBase(id=98, name='relativehumidity', units='%', display_name='RH')), SensorBase(id=9648811, name='temperature c', parameter=ParameterBase(id=100, name='temperature', units='c', display_name='Temperature (C)')), SensorBase(id=9648796, name='um003 particles/cm³', parameter=ParameterBase(id=125, name='um003', units='particles/cm³', display_name='PM0.3 count'))], coordinates=Coordinates(latitude=40.708, longitude=-73.944), bounds=[-73.944, 40.708, -73.944, 40.708], distance=None, datetime_first=Datetime(utc='2024-06-19T01:00:00Z', local='2024-06-18T21:00:00-04:00'), datetime_last=Datetime(utc='2025-04-22T18:00:00Z', local='2025-04-22T14:00:00-04:00')),
#  Location(id=3041962, name='Near Bay 50 St', locality=None, timezone='America/New_York', country=CountryBase(id=155, code='US', name='United States'), owner=OwnerBase(id=11137, name='Sebastian'), provider=ProviderBase(id=66, name='AirGradient'), is_mobile=False, is_monitor=False, instruments=[InstrumentBase(id=7, name='AirGradient Sensor')], sensors=[SensorBase(id=10454057, name='pm1 µg/m³', parameter=ParameterBase(id=19, name='pm1', units='µg/m³', display_name='PM1')), SensorBase(id=10454082, name='pm10 µg/m³', parameter=ParameterBase(id=1, name='pm10', units='µg/m³', display_name='PM10')), SensorBase(id=10454043, name='pm25 µg/m³', parameter=ParameterBase(id=2, name='pm25', units='µg/m³', display_name='PM2.5')), SensorBase(id=10454068, name='relativehumidity %', parameter=ParameterBase(id=98, name='relativehumidity', units='%', display_name='RH')), SensorBase(id=10454036, name='temperature c', parameter=ParameterBase(id=100, name='temperature', units='c', display_name='Temperature (C)')), SensorBase(id=10454078, name='um003 particles/cm³', parameter=ParameterBase(id=125, name='um003', units='particles/cm³', display_name='PM0.3 count'))], coordinates=Coordinates(latitude=40.5887458, longitude=-73.9838231), bounds=[-73.9838231, 40.5887458, -73.9838231, 40.5887458], distance=None, datetime_first=Datetime(utc='2024-08-31T19:00:00Z', local='2024-08-31T15:00:00-04:00'), datetime_last=Datetime(utc='2025-04-22T18:00:00Z', local='2025-04-22T14:00:00-04:00')),
#  Location(id=3103622, name='Montclair, NJ', locality=None, timezone='America/New_York', country=CountryBase(id=155, code='US', name='United States'), owner=OwnerBase(id=4032, name='William'), provider=ProviderBase(id=66, name='AirGradient'), is_mobile=False, is_monitor=False, instruments=[InstrumentBase(id=7, name='AirGradient Sensor')], sensors=[SensorBase(id=10888556, name='pm1 µg/m³', parameter=ParameterBase(id=19, name='pm1', units='µg/m³', display_name='PM1')), SensorBase(id=10888566, name='pm10 µg/m³', parameter=ParameterBase(id=1, name='pm10', units='µg/m³', display_name='PM10')), SensorBase(id=10888589, name='pm25 µg/m³', parameter=ParameterBase(id=2, name='pm25', units='µg/m³', display_name='PM2.5')), SensorBase(id=10888578, name='relativehumidity %', parameter=ParameterBase(id=98, name='relativehumidity', units='%', display_name='RH')), SensorBase(id=10888539, name='temperature c', parameter=ParameterBase(id=100, name='temperature', units='c', display_name='Temperature (C)')), SensorBase(id=10888579, name='um003 particles/cm³', parameter=ParameterBase(id=125, name='um003', units='particles/cm³', display_name='PM0.3 count'))], coordinates=Coordinates(latitude=40.8476775, longitude=-74.2065738), bounds=[-74.2065738, 40.8476775, -74.2065738, 40.8476775], distance=None, datetime_first=Datetime(utc='2024-10-09T04:00:00Z', local='2024-10-09T00:00:00-04:00'), datetime_last=Datetime(utc='2025-04-22T18:00:00Z', local='2025-04-22T14:00:00-04:00')),
#  Location(id=3145067, name='Metal fence on PS9 back campus [NYC Testbed Pilot]', locality=None, timezone='America/New_York', country=CountryBase(id=155, code='US', name='United States'), owner=OwnerBase(id=9, name='Clarity'), provider=ProviderBase(id=166, name='Clarity'), is_mobile=False, is_monitor=False, instruments=[InstrumentBase(id=4, name='Clarity Sensor')], sensors=[SensorBase(id=10986460, name='pm25 µg/m³', parameter=ParameterBase(id=2, name='pm25', units='µg/m³', display_name='PM2.5'))], coordinates=Coordinates(latitude=40.7182, longitude=-73.91277), bounds=[-73.91277, 40.7182, -73.91277, 40.7182], distance=None, datetime_first=Datetime(utc='2024-10-17T15:05:14Z', local='2024-10-17T11:05:14-04:00'), datetime_last=Datetime(utc='2024-12-05T15:06:32Z', local='2024-12-05T10:06:32-05:00')),
#  Location(id=3145068, name='56th St & Flushing [NYC Testbed Pilot]', locality=None, timezone='America/New_York', country=CountryBase(id=155, code='US', name='United States'), owner=OwnerBase(id=9, name='Clarity'), provider=ProviderBase(id=166, name='Clarity'), is_mobile=False, is_monitor=False, instruments=[InstrumentBase(id=4, name='Clarity Sensor')], sensors=[SensorBase(id=10986466, name='pm25 µg/m³', parameter=ParameterBase(id=2, name='pm25', units='µg/m³', display_name='PM2.5'))], coordinates=Coordinates(latitude=40.718, longitude=-73.91277), bounds=[-73.91277, 40.718, -73.91277, 40.718], distance=None, datetime_first=Datetime(utc='2024-10-17T15:05:17Z', local='2024-10-17T11:05:17-04:00'), datetime_last=Datetime(utc='2024-12-05T15:06:05Z', local='2024-12-05T10:06:05-05:00')),
#  Location(id=3145069, name='Closest to SA unit on PS9 campus', locality=None, timezone='America/New_York', country=CountryBase(id=155, code='US', name='United States'), owner=OwnerBase(id=9, name='Clarity'), provider=ProviderBase(id=166, name='Clarity'), is_mobile=False, is_monitor=False, instruments=[InstrumentBase(id=4, name='Clarity Sensor')], sensors=[SensorBase(id=10986467, name='pm25 µg/m³', parameter=ParameterBase(id=2, name='pm25', units='µg/m³', display_name='PM2.5'))], coordinates=Coordinates(latitude=40.71825, longitude=-73.91263), bounds=[-73.91263, 40.71825, -73.91263, 40.71825], distance=None, datetime_first=Datetime(utc='2024-10-17T15:04:50Z', local='2024-10-17T11:04:50-04:00'), datetime_last=Datetime(utc='2024-12-05T15:06:11Z', local='2024-12-05T10:06:11-05:00')),
#  Location(id=3145070, name=' 57th St/Front of School [NYC Testbed Pilot]', locality=None, timezone='America/New_York', country=CountryBase(id=155, code='US', name='United States'), owner=OwnerBase(id=9, name='Clarity'), provider=ProviderBase(id=166, name='Clarity'), is_mobile=False, is_monitor=False, instruments=[InstrumentBase(id=4, name='Clarity Sensor')], sensors=[SensorBase(id=10986463, name='pm25 µg/m³', parameter=ParameterBase(id=2, name='pm25', units='µg/m³', display_name='PM2.5'))], coordinates=Coordinates(latitude=40.71872, longitude=-73.91207), bounds=[-73.91207, 40.71872, -73.91207, 40.71872], distance=None, datetime_first=Datetime(utc='2024-10-17T15:03:32Z', local='2024-10-17T11:03:32-04:00'), datetime_last=Datetime(utc='2024-12-05T15:03:52Z', local='2024-12-05T10:03:52-05:00')),
#  Location(id=3145072, name='54th St & Flushing [NYC Testbed Pilot]', locality=None, timezone='America/New_York', country=CountryBase(id=155, code='US', name='United States'), owner=OwnerBase(id=9, name='Clarity'), provider=ProviderBase(id=166, name='Clarity'), is_mobile=False, is_monitor=False, instruments=[InstrumentBase(id=4, name='Clarity Sensor')], sensors=[SensorBase(id=10986461, name='pm25 µg/m³', parameter=ParameterBase(id=2, name='pm25', units='µg/m³', display_name='PM2.5'))], coordinates=Coordinates(latitude=40.71641, longitude=-73.91392), bounds=[-73.91392, 40.71641, -73.91392, 40.71641], distance=None, datetime_first=Datetime(utc='2024-10-17T15:03:10Z', local='2024-10-17T11:03:10-04:00'), datetime_last=Datetime(utc='2024-12-05T15:05:03Z', local='2024-12-05T10:05:03-05:00')),
#  Location(id=3145073, name='56th St & Grand Ave [NYC Testbed Pilot]', locality=None, timezone='America/New_York', country=CountryBase(id=155, code='US', name='United States'), owner=OwnerBase(id=9, name='Clarity'), provider=ProviderBase(id=166, name='Clarity'), is_mobile=False, is_monitor=False, instruments=[InstrumentBase(id=4, name='Clarity Sensor')], sensors=[SensorBase(id=10986465, name='pm25 µg/m³', parameter=ParameterBase(id=2, name='pm25', units='µg/m³', display_name='PM2.5'))], coordinates=Coordinates(latitude=40.71834, longitude=-73.91295), bounds=[-73.91295, 40.71834, -73.91295, 40.71834], distance=None, datetime_first=Datetime(utc='2024-10-17T15:01:10Z', local='2024-10-17T11:01:10-04:00'), datetime_last=Datetime(utc='2024-12-05T15:07:01Z', local='2024-12-05T10:07:01-05:00')),
#  Location(id=3145074, name=' 54th St & Grand Ave [NYC Testbed Pilot]', locality=None, timezone='America/New_York', country=CountryBase(id=155, code='US', name='United States'), owner=OwnerBase(id=9, name='Clarity'), provider=ProviderBase(id=166, name='Clarity'), is_mobile=False, is_monitor=False, instruments=[InstrumentBase(id=4, name='Clarity Sensor')], sensors=[SensorBase(id=10986462, name='pm25 µg/m³', parameter=ParameterBase(id=2, name='pm25', units='µg/m³', display_name='PM2.5'))], coordinates=Coordinates(latitude=40.71762, longitude=-73.91458), bounds=[-73.91458, 40.71762, -73.91458, 40.71762], distance=None, datetime_first=Datetime(utc='2024-10-17T15:04:52Z', local='2024-10-17T11:04:52-04:00'), datetime_last=Datetime(utc='2024-12-05T15:05:35Z', local='2024-12-05T10:05:35-05:00')),
#  Location(id=3181018, name='Hillcrest, NY', locality=None, timezone='America/New_York', country=CountryBase(id=155, code='US', name='United States'), owner=OwnerBase(id=11509, name='Unknown Person'), provider=ProviderBase(id=66, name='AirGradient'), is_mobile=False, is_monitor=False, instruments=[InstrumentBase(id=7, name='AirGradient Sensor')], sensors=[SensorBase(id=11074566, name='pm1 µg/m³', parameter=ParameterBase(id=19, name='pm1', units='µg/m³', display_name='PM1')), SensorBase(id=11074572, name='pm10 µg/m³', parameter=ParameterBase(id=1, name='pm10', units='µg/m³', display_name='PM10')), SensorBase(id=11074571, name='pm25 µg/m³', parameter=ParameterBase(id=2, name='pm25', units='µg/m³', display_name='PM2.5')), SensorBase(id=11074582, name='relativehumidity %', parameter=ParameterBase(id=98, name='relativehumidity', units='%', display_name='RH')), SensorBase(id=11074585, name='temperature c', parameter=ParameterBase(id=100, name='temperature', units='c', display_name='Temperature (C)')), SensorBase(id=11074587, name='um003 particles/cm³', parameter=ParameterBase(id=125, name='um003', units='particles/cm³', display_name='PM0.3 count'))], coordinates=Coordinates(latitude=40.718438547, longitude=-73.8016837), bounds=[-73.8016837, 40.718438547, -73.8016837, 40.718438547], distance=None, datetime_first=Datetime(utc='2024-10-25T10:00:00Z', local='2024-10-25T06:00:00-04:00'), datetime_last=Datetime(utc='2025-04-22T18:00:00Z', local='2025-04-22T14:00:00-04:00')),
#  Location(id=3305066, name='Downtown Montclair', locality=None, timezone='America/New_York', country=CountryBase(id=155, code='US', name='United States'), owner=OwnerBase(id=11286, name='Downtown Montclair'), provider=ProviderBase(id=66, name='AirGradient'), is_mobile=False, is_monitor=False, instruments=[InstrumentBase(id=7, name='AirGradient Sensor')], sensors=[SensorBase(id=11571199, name='pm1 µg/m³', parameter=ParameterBase(id=19, name='pm1', units='µg/m³', display_name='PM1')), SensorBase(id=11571193, name='pm10 µg/m³', parameter=ParameterBase(id=1, name='pm10', units='µg/m³', display_name='PM10')), SensorBase(id=11571194, name='pm25 µg/m³', parameter=ParameterBase(id=2, name='pm25', units='µg/m³', display_name='PM2.5')), SensorBase(id=11571192, name='relativehumidity %', parameter=ParameterBase(id=98, name='relativehumidity', units='%', display_name='RH')), SensorBase(id=11571197, name='temperature c', parameter=ParameterBase(id=100, name='temperature', units='c', display_name='Temperature (C)')), SensorBase(id=11571202, name='um003 particles/cm³', parameter=ParameterBase(id=125, name='um003', units='particles/cm³', display_name='PM0.3 count'))], coordinates=Coordinates(latitude=40.81405, longitude=-74.21782), bounds=[-74.21782, 40.81405, -74.21782, 40.81405], distance=None, datetime_first=Datetime(utc='2024-12-08T04:00:00Z', local='2024-12-07T23:00:00-05:00'), datetime_last=Datetime(utc='2025-04-22T18:00:00Z', local='2025-04-22T14:00:00-04:00')),
#  Location(id=3400913, name='DropHome', locality=None, timezone='America/New_York', country=CountryBase(id=155, code='US', name='United States'), owner=OwnerBase(id=11347, name='kan84'), provider=ProviderBase(id=66, name='AirGradient'), is_mobile=False, is_monitor=False, instruments=[InstrumentBase(id=7, name='AirGradient Sensor')], sensors=[SensorBase(id=12178175, name='pm1 µg/m³', parameter=ParameterBase(id=19, name='pm1', units='µg/m³', display_name='PM1')), SensorBase(id=12178176, name='pm25 µg/m³', parameter=ParameterBase(id=2, name='pm25', units='µg/m³', display_name='PM2.5')), SensorBase(id=12178177, name='relativehumidity %', parameter=ParameterBase(id=98, name='relativehumidity', units='%', display_name='RH')), SensorBase(id=12178178, name='temperature c', parameter=ParameterBase(id=100, name='temperature', units='c', display_name='Temperature (C)')), SensorBase(id=12178491, name='um003 particles/cm³', parameter=ParameterBase(id=125, name='um003', units='particles/cm³', display_name='PM0.3 count'))], coordinates=Coordinates(latitude=40.776416, longitude=-73.981338), bounds=[-73.981338, 40.776416, -73.981338, 40.776416], distance=None, datetime_first=Datetime(utc='2025-02-11T18:00:00Z', local='2025-02-11T13:00:00-05:00'), datetime_last=Datetime(utc='2025-04-22T18:00:00Z', local='2025-04-22T14:00:00-04:00')),
#  Location(id=3406357, name='Bayside, NY 11361', locality=None, timezone='America/New_York', country=CountryBase(id=155, code='US', name='United States'), owner=OwnerBase(id=11509, name='Unknown Person'), provider=ProviderBase(id=66, name='AirGradient'), is_mobile=False, is_monitor=False, instruments=[InstrumentBase(id=7, name='AirGradient Sensor')], sensors=[SensorBase(id=12212726, name='pm1 µg/m³', parameter=ParameterBase(id=19, name='pm1', units='µg/m³', display_name='PM1')), SensorBase(id=12212727, name='pm25 µg/m³', parameter=ParameterBase(id=2, name='pm25', units='µg/m³', display_name='PM2.5')), SensorBase(id=12212728, name='relativehumidity %', parameter=ParameterBase(id=98, name='relativehumidity', units='%', display_name='RH')), SensorBase(id=12212729, name='temperature c', parameter=ParameterBase(id=100, name='temperature', units='c', display_name='Temperature (C)')), SensorBase(id=12212730, name='um003 particles/cm³', parameter=ParameterBase(id=125, name='um003', units='particles/cm³', display_name='PM0.3 count'))], coordinates=Coordinates(latitude=40.76433675598798, longitude=-73.76633802306293), bounds=[-73.76633802306293, 40.76433675598798, -73.76633802306293, 40.76433675598798], distance=None, datetime_first=Datetime(utc='2025-02-16T16:00:00Z', local='2025-02-16T11:00:00-05:00'), datetime_last=Datetime(utc='2025-04-22T18:00:00Z', local='2025-04-22T14:00:00-04:00'))]

# %%
# Specific result for one sensor
ny_bbox_search_locations.results[0].__dict__
# Out:
# {'id': 384,
#  'name': 'CCNY',
#  'locality': 'New York-Northern New Jersey-Long Island',
#  'timezone': 'America/New_York',
#  'country': CountryBase(id=155, code='US', name='United States'),
#  'owner': OwnerBase(id=4, name='Unknown Governmental Organization'),
#  'provider': ProviderBase(id=119, name='AirNow'),
#  'is_mobile': False,
#  'is_monitor': True,
#  'instruments': [InstrumentBase(id=2, name='Government Monitor')],
#  'sensors': [SensorBase(id=671, name='o3 ppm', parameter=ParameterBase(id=10, name='o3', units='ppm', display_name='O₃')),
#   SensorBase(id=673, name='pm25 µg/m³', parameter=ParameterBase(id=2, name='pm25', units='µg/m³', display_name='PM2.5'))],
#  'coordinates': Coordinates(latitude=40.8197, longitude=-73.9481),
#  'bounds': [-73.9481, 40.8197, -73.9481, 40.8197],
#  'distance': None,
#  'datetime_first': Datetime(utc='2016-03-12T09:00:00Z', local='2016-03-12T04:00:00-05:00'),
#  'datetime_last': Datetime(utc='2025-04-22T18:00:00Z', local='2025-04-22T14:00:00-04:00')}

# %%
# Create a dictionary containing id and name
locations_info = {}
for location in ny_bbox_search_locations.results:
    locations_info[location.id] = location.name
locations_info
# Out:
# {384: 'CCNY',
#  386: 'Susan Wagner',
#  392: 'Babylon',
#  625: 'Manhattan/IS143',
#  626: 'Bronx - IS52',
#  628: 'Maspeth',
#  631: 'Queens',
#  642: 'PS 19',
#  648: 'Bklyn - PS 314',
#  661: 'Eisenhower Park',
#  662: 'Division Street',
#  664: 'Bklyn - PS274',
#  665: 'Bronx - IS74',
#  666: 'Pfizer Lab',
#  853: 'East Orange',
#  857: 'Fort Lee Near Road',
#  924: 'Rahway PM',
#  928: 'Jersey City FH',
#  971: 'Elizabeth Trailer',
#  974: 'Newark Firehouse',
#  984: 'Leonia',
#  1122: 'Jersey City',
#  1496: 'Bayonne',
#  2193: 'Elizabeth',
#  8749: 'Queens Near-road',
#  292229: 'Morrisania',
#  387315: 'Union City High Scho',
#  391818: 'Paterson',
#  496096: 'Port Richmond',
#  1236005: 'Larchmont, NY',
#  1236043: 'Franklin Avenue',
#  1738519: 'Bayside, NY',
#  1775647: 'State Dept of Environmental Conservation',
#  1824516: 'Bayside, NY',
#  2153518: 'Jersey City Heights',
#  2386747: 'Carteret, NJ',
#  2453305: 'State Dept of Environmental Conservation',
#  2453313: 'State Dept of Environmental Conservation',
#  2616564: '7th Ave and W 16th St',
#  2903996: 'Win Son',
#  3041962: 'Near Bay 50 St',
#  3103622: 'Montclair, NJ',
#  3145067: 'Metal fence on PS9 back campus [NYC Testbed Pilot]',
#  3145068: '56th St & Flushing [NYC Testbed Pilot]',
#  3145069: 'Closest to SA unit on PS9 campus',
#  3145070: ' 57th St/Front of School [NYC Testbed Pilot]',
#  3145072: '54th St & Flushing [NYC Testbed Pilot]',
#  3145073: '56th St & Grand Ave [NYC Testbed Pilot]',
#  3145074: ' 54th St & Grand Ave [NYC Testbed Pilot]',
#  3181018: 'Hillcrest, NY',
#  3305066: 'Downtown Montclair',
#  3400913: 'DropHome',
#  3406357: 'Bayside, NY 11361'}

# %%
# Save the dictionary as a json file
with open("../locations.json", "w", encoding = "utf-8") as f:
    json.dump(locations_info, f, ensure_ascii = False, indent = 4)
    f.close()
